# %%
import pandas as pd

apl_data = [
    # Features, Model, Recall_mean, Recall_std, F1_mean, F1_std, ROC_mean, ROC_std, PR_mean, PR_std
    ("X",   "RF", 0.77,0.05, 0.61,0.01, 0.84,0.02, 0.62,0.04),
    ("X",   "GB", 0.63,0.04, 0.62,0.03, 0.85,0.01, 0.64,0.07),
    ("X",   "LR", 0.69,0.05, 0.46,0.01, 0.68,0.02, 0.37,0.01),
    ("X",  "XGB", 0.71,0.06, 0.63,0.01, 0.85,0.01, 0.66,0.03),
    ("X",   "CB", 0.73,0.03, 0.64,0.02, 0.86,0.01, 0.66,0.02),

    ("M",   "RF", 0.87,0.07, 0.50,0.04, 0.78,0.03, 0.50,0.05),
    ("M",   "GB", 0.67,0.02, 0.56,0.02, 0.79,0.02, 0.53,0.04),
    ("M",   "LR", 0.62,0.02, 0.53,0.02, 0.76,0.03, 0.48,0.03),
    ("M",  "XGB", 0.76,0.05, 0.58,0.04, 0.80,0.03, 0.55,0.05),
    ("M",   "CB", 0.69,0.05, 0.56,0.03, 0.80,0.01, 0.53,0.02),

    ("D",   "RF", 0.72,0.03, 0.58,0.02, 0.81,0.02, 0.54,0.06),
    ("D",   "GB", 0.60,0.03, 0.59,0.04, 0.56,0.03, 0.58,0.07),
    ("D",   "LR", 0.68,0.03, 0.55,0.03, 0.77,0.02, 0.48,0.05),
    ("D",  "XGB", 0.74,0.04, 0.58,0.02, 0.81,0.02, 0.55,0.04),
    ("D",   "CB", 0.75,0.04, 0.59,0.03, 0.81,0.02, 0.55,0.05),

    ("XD",  "RF", 0.80,0.04, 0.64,0.03, 0.84,0.01, 0.61,0.05),
    ("XD",  "GB", 0.65,0.03, 0.64,0.03, 0.86,0.02, 0.66,0.05),
    ("XD",  "LR", 0.69,0.05, 0.46,0.01, 0.68,0.02, 0.37,0.00),
    ("XD", "XGB", 0.71,0.06, 0.64,0.01, 0.86,0.01, 0.67,0.03),
    ("XD",  "CB", 0.74,0.05, 0.65,0.01, 0.86,0.01, 0.66,0.01),

    ("MD",  "RF", 0.71,0.04, 0.58,0.02, 0.81,0.02, 0.54,0.05),
    ("MD",  "GB", 0.67,0.04, 0.57,0.05, 0.80,0.03, 0.54,0.06),
    ("MD",  "LR", 0.60,0.02, 0.52,0.02, 0.75,0.02, 0.47,0.04),
    ("MD", "XGB", 0.77,0.03, 0.58,0.02, 0.80,0.02, 0.54,0.03),
    ("MD",  "CB", 0.75,0.03, 0.59,0.03, 0.82,0.02, 0.57,0.05),

    ("XMD", "RF", 0.84,0.04, 0.60,0.03, 0.84,0.02, 0.62,0.04),
    ("XMD", "GB", 0.66,0.04, 0.64,0.02, 0.85,0.01, 0.66,0.03),
    ("XMD", "LR", 0.69,0.05, 0.46,0.01, 0.68,0.02, 0.37,0.00),
    ("XMD","XGB", 0.69,0.07, 0.64,0.03, 0.86,0.01, 0.67,0.03),
    ("XMD", "CB", 0.75,0.03, 0.65,0.01, 0.86,0.01, 0.68,0.01),
]

apl_df = pd.DataFrame(apl_data, columns=[
    "Features", "Model",
    "Recall_mean", "Recall_std",
    "F1_mean", "F1_std",
    "ROC_mean", "ROC_std",
    "PR_mean", "PR_std"
])

apl_df.head()
# Out:
#   Features Model  Recall_mean  Recall_std  F1_mean  F1_std  ROC_mean  ROC_std  \
# 0        X    RF         0.77        0.05     0.61    0.01      0.84     0.02
# 1        X    GB         0.63        0.04     0.62    0.03      0.85     0.01
# 2        X    LR         0.69        0.05     0.46    0.01      0.68     0.02
# 3        X   XGB         0.71        0.06     0.63    0.01      0.85     0.01
# 4        X    CB         0.73        0.03     0.64    0.02      0.86     0.01
#
#    PR_mean  PR_std
# 0     0.62    0.04
# 1     0.64    0.07
# 2     0.37    0.01
# 3     0.66    0.03
# 4     0.66    0.02

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np


def plot_model_performance(cohort_df, cohort_name, target_name):
    # Define feature order and colors/markers for metrics
    feature_order = ["X", "M", "D", "XD", "MD", "XMD"]
    metric_colors = {
        "ROC": "#1f77b4",  # blue
        "PR": "#ff7f0e",  # orange
        "F1": "#2ca02c",  # green
        "Recall": "#d62728",  # red
    }
    metric_markers = {
        "ROC": "D",
        "PR": "o",
        "F1": "s",
        "Recall": "^",
    }  # diamond = "D", circle = "o"
    metrics = ["ROC", "PR", "F1", "Recall"]

    models_dict = {
        "RF": "Random Forest",
        "GB": "Gradient Boosting",
        "LR": "Logistic Regression",
        "XGB": "XGBoost",
        "CB": "CatBoost",
    }

    # Iterate over models
    for model in cohort_df["Model"].unique():
        model_data = cohort_df[cohort_df["Model"] == model].copy()
        model_data["Features"] = pd.Categorical(
            model_data["Features"], categories=feature_order, ordered=True
        )
        model_data = model_data.sort_values("Features")

        # Change figure size for vertical orientation
        fig, ax = plt.subplots(figsize=(8, 10))  # Taller aspect ratio for vertical plot

        # Plot each metric - SWAP X AND Y AXES
        for metric in metrics:
            ax.errorbar(
                model_data["Features"],  # X-axis now features
                model_data[f"{metric}_mean"],  # Y-axis now metric values
                yerr=model_data[f"{metric}_std"],  # yerr instead of xerr
                fmt=metric_markers[metric],
                markersize=10,
                color=metric_colors[metric],
                ecolor=metric_colors[metric],
                elinewidth=2,
                capsize=6,
                label=metric,
                linestyle="--",
                linewidth=1,
                markeredgecolor="white",
                markeredgewidth=1.5,
            )

        # Performance thresholds - NOW HORIZONTAL LINES
        ax.axhspan(
            0.8, 0.9, color="#2E8B57", alpha=0.15, label="Good (0.8–0.9)"
        )  # Sea Green
        ax.axhspan(
            0.7, 0.8, color="#FFA500", alpha=0.15, label="Fair (0.7–0.8)"
        )  # Orange
        ax.axhline(0.8, color="#2E8B57", linestyle="--", linewidth=1.5, alpha=0.7)
        ax.axhline(0.7, color="#FFA500", linestyle="--", linewidth=1.5, alpha=0.7)

        # Set major and minor ticks on Y-axis instead of X-axis
        major_ticks = np.arange(0.0, 0.91, 0.1)
        ax.set_yticks(major_ticks)

        minor_ticks = np.arange(0.01, 0.91, 0.01)
        ax.set_yticks(minor_ticks, minor=True)

        # Configure Y-axis ticks instead of X-axis
        ax.tick_params(axis="y", which="major", length=10)
        ax.tick_params(axis="y", which="minor", length=5)

        # Rotate x-axis labels for better readability
        ax.tick_params(axis="x", rotation=45)

        # Titles and labels - SWAPPED
        ax.set_title(f"{models_dict[model]} Performance", fontsize=16)
        ax.set_ylabel("Score (Mean ± Standard Deviation)", fontsize=16)
        ax.set_xlabel("Feature Set", fontsize=16)
        low, high = (
            model_data[[f"{m}_mean" for m in metrics]].min().min(),
            model_data[[f"{m}_mean" for m in metrics]].max().max(),
        )
        ax.set_ylim(max(0.0, low - 0.05), min(0.9, high + 0.05))

        # ax.set_ylim(0.0, 0.9)  # ylim instead of xlim

        # Grid on Y-axis instead of default (both)
        ax.grid(
            True, axis="y", color="lightgray", linestyle="--", linewidth=0.7, alpha=0.7
        )
        ax.legend(fontsize=10)

        fig.tight_layout()

        # Save as PDF
        fig.savefig(
            f"{cohort_name}_{target_name}_{model}_metrics.pdf",
            format="pdf",
            bbox_inches="tight",
        )
        plt.close(fig)


plot_model_performance(apl_df, "APL", "Clinical_Target")

# %%
import pandas as pd

apl_demographic = [
    # Target, Features, Model, Recall_mean, Recall_std, F1_mean, F1_std, ROC_mean, ROC_std, PR_mean, PR_std
    
    # Gender
    ("Gender","M","RF",0.55,0.03,0.55,0.03,0.54,0.02,0.57,0.05),
    ("Gender","M","GB",0.55,0.04,0.54,0.02,0.52,0.01,0.55,0.06),
    ("Gender","M","LR",0.56,0.01,0.56,0.01,0.53,0.02,0.55,0.04),
    ("Gender","M","XGB",0.98,0.01,0.69,0.03,0.52,0.02,0.56,0.06),
    ("Gender","M","CB",0.46,0.22,0.48,0.20,0.54,0.02,0.57,0.06),

    ("Gender","D","RF",0.56,0.04,0.57,0.04,0.57,0.02,0.60,0.06),
    ("Gender","D","GB",0.60,0.03,0.59,0.04,0.56,0.03,0.58,0.07),
    ("Gender","D","LR",0.60,0.01,0.58,0.02,0.56,0.02,0.58,0.04),
    ("Gender","D","XGB",0.96,0.01,0.69,0.03,0.55,0.01,0.57,0.06),
    ("Gender","D","CB",0.57,0.02,0.57,0.03,0.56,0.02,0.59,0.05),

    ("Gender","MD","RF",0.55,0.05,0.56,0.04,0.57,0.02,0.57,0.06),
    ("Gender","MD","GB",0.58,0.03,0.57,0.01,0.56,0.01,0.58,0.03),
    ("Gender","MD","LR",0.56,0.01,0.56,0.01,0.56,0.01,0.56,0.04),
    ("Gender","MD","XGB",0.93,0.04,0.68,0.04,0.56,0.03,0.58,0.07),
    ("Gender","MD","CB",0.57,0.03,0.57,0.04,0.57,0.02,0.59,0.05),

    # Race
    ("Race","M","RF",0.74,0.30,0.49,0.09,0.53,0.02,0.42,0.05),
    ("Race","M","GB",0.48,0.04,0.45,0.02,0.54,0.03,0.42,0.06),
    ("Race","M","LR",0.49,0.05,0.45,0.00,0.55,0.03,0.42,0.04),
    ("Race","M","XGB",0.76,0.12,0.52,0.01,0.55,0.02,0.43,0.05),
    ("Race","M","CB",0.51,0.05,0.46,0.02,0.56,0.02,0.44,0.05),

    ("Race","D","RF",0.74,0.30,0.49,0.09,0.53,0.02,0.42,0.05),
    ("Race","D","GB",0.44,0.01,0.43,0.02,0.55,0.02,0.43,0.02),
    ("Race","D","LR",0.46,0.05,0.43,0.02,0.54,0.02,0.43,0.05),
    ("Race","D","XGB",0.74,0.15,0.52,0.04,0.55,0.02,0.43,0.05),
    ("Race","D","CB",0.53,0.04,0.48,0.02,0.57,0.02,0.44,0.05),

    ("Race","MD","RF",0.84,0.18,0.53,0.05,0.55,0.01,0.43,0.05),
    ("Race","MD","GB",0.47,0.01,0.46,0.02,0.56,0.01,0.44,0.03),
    ("Race","MD","LR",0.49,0.06,0.46,0.01,0.56,0.01,0.44,0.05),
    ("Race","MD","XGB",0.76,0.03,0.53,0.03,0.55,0.02,0.44,0.06),
    ("Race","MD","CB",0.50,0.03,0.46,0.01,0.56,0.02,0.44,0.04),

    # Age
    ("Age","M","RF",0.69,0.03,0.75,0.02,0.61,0.02,0.83,0.03),
    ("Age","M","GB",0.73,0.01,0.77,0.01,0.61,0.02,0.83,0.02),
    ("Age","M","LR",0.70,0.01,0.75,0.01,0.59,0.03,0.83,0.03),
    ("Age","M","XGB",0.85,0.08,0.82,0.04,0.61,0.02,0.84,0.03),
    ("Age","M","CB",0.64,0.06,0.72,0.04,0.63,0.04,0.84,0.04),

    ("Age","D","RF",0.56,0.04,0.57,0.04,0.57,0.02,0.60,0.06),
    ("Age","D","GB",0.60,0.03,0.59,0.04,0.56,0.03,0.58,0.07),
    ("Age","D","LR",0.60,0.01,0.58,0.02,0.56,0.02,0.58,0.04),
    ("Age","D","XGB",0.96,0.01,0.69,0.03,0.55,0.01,0.57,0.06),
    ("Age","D","CB",0.57,0.02,0.57,0.03,0.56,0.02,0.59,0.05),

    ("Age","MD","RF",0.72,0.03,0.77,0.02,0.63,0.02,0.84,0.03),
    ("Age","MD","GB",0.72,0.01,0.76,0.02,0.61,0.01,0.83,0.03),
    ("Age","MD","LR",0.68,0.02,0.75,0.01,0.62,0.05,0.84,0.04),
    ("Age","MD","XGB",0.83,0.05,0.82,0.03,0.63,0.03,0.84,0.04),
    ("Age","MD","CB",0.66,0.02,0.74,0.01,0.65,0.03,0.85,0.03),
]

apl_demographic_df = pd.DataFrame(apl_demographic, columns=[
    "Target","Features","Model",
    "Recall_mean","Recall_std",
    "F1_mean","F1_std",
    "ROC_mean","ROC_std",
    "PR_mean","PR_std"
])

apl_demographic_df.head()
# Out:
#    Target Features Model  Recall_mean  Recall_std  F1_mean  F1_std  ROC_mean  \
# 0  Gender        M    RF         0.55        0.03     0.55    0.03      0.54
# 1  Gender        M    GB         0.55        0.04     0.54    0.02      0.52
# 2  Gender        M    LR         0.56        0.01     0.56    0.01      0.53
# 3  Gender        M   XGB         0.98        0.01     0.69    0.03      0.52
# 4  Gender        M    CB         0.46        0.22     0.48    0.20      0.54
#
#    ROC_std  PR_mean  PR_std
# 0     0.02     0.57    0.05
# 1     0.01     0.55    0.06
# 2     0.02     0.55    0.04
# 3     0.02     0.56    0.06
# 4     0.02     0.57    0.06

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

def plot_demographic_roc_pr(cohort_df, cohort_name):
    # Define settings
    feature_order = ["M", "D", "MD"]
    metrics = ["ROC", "PR"]
    metric_colors = {
        "ROC": "#1f77b4",  # blue
        "PR": "#ff7f0e",  # orange
    }
    metric_markers = {
        "ROC": "D",
        "PR": "o",
    }
    
    models_dict = {
        "RF": "Random Forest",
        "GB": "Gradient Boosting",
        "LR": "Logistic Regression",
        "XGB": "XGBoost",
        "CB": "CatBoost",
    }
    
    target_order = ["Age", "Gender", "Race"]
    target_titles = {
        "Age": "Age Prediction",
        "Gender": "Gender Prediction", 
        "Race": "Race Prediction"
    }

    # Iterate over models
    for model in cohort_df["Model"].unique():
        model_data = cohort_df[cohort_df["Model"] == model].copy()
        
        # Create figure with 3 columns (one for each target)
        fig, axes = plt.subplots(1, 3, figsize=(18, 6))  # 3 columns, wider figure
        
        # Plot each target in its own subplot
        for idx, target in enumerate(target_order):
            ax = axes[idx]
            target_model_data = model_data[model_data["Target"] == target].copy()
            target_model_data["Features"] = pd.Categorical(
                target_model_data["Features"], categories=feature_order, ordered=True
            )
            target_model_data = target_model_data.sort_values("Features")
            
            # Plot ROC and PR for this target
            for metric in metrics:
                ax.errorbar(
                    target_model_data["Features"],
                    target_model_data[f"{metric}_mean"],
                    yerr=target_model_data[f"{metric}_std"],
                    fmt=metric_markers[metric],
                    markersize=10,
                    color=metric_colors[metric],
                    ecolor=metric_colors[metric],
                    elinewidth=2,
                    capsize=6,
                    label=metric,
                    linestyle="--",
                    linewidth=1.5,
                    markeredgecolor="white",
                    markeredgewidth=1.5,
                )
            
            # Performance thresholds
            ax.axhspan(0.8, 0.9, color="#2E8B57", alpha=0.15, label="Good (0.8–0.9)")
            ax.axhspan(0.7, 0.8, color="#FFA500", alpha=0.15, label="Fair (0.7–0.8)")
            ax.axhline(0.8, color="#2E8B57", linestyle="--", linewidth=1.5, alpha=0.7)
            ax.axhline(0.7, color="#FFA500", linestyle="--", linewidth=1.5, alpha=0.7)
            
            # Configure subplot
            ax.set_title(target_titles[target], fontsize=14, fontweight='bold')
            ax.set_ylabel("Score (Mean ± SD)", fontsize=16)
            ax.set_xlabel("Feature Set", fontsize=16)
            
            all_values = []
            for metric in metrics:
                all_values.extend(target_model_data[f"{metric}_mean"].values)
                all_values.extend(
                    (target_model_data[f"{metric}_mean"] - target_model_data[f"{metric}_std"]).values
                )
                all_values.extend(
                    (target_model_data[f"{metric}_mean"] + target_model_data[f"{metric}_std"]).values
                )

            # Compute min and max with padding
            y_min = max(0.0, np.min(all_values) - 0.05)
            y_max = min(1.0, np.max(all_values) + 0.05)

            ax.set_ylim(y_min, y_max)
            
            # Set ticks
            major_ticks = np.arange(y_min, y_max, 0.2)
            minor_ticks = np.arange(y_min, y_max, 0.01)
            ax.set_yticks(major_ticks)
            ax.set_yticks(minor_ticks, minor=True)
            
            ax.tick_params(axis='y', which='major', length=8)
            ax.tick_params(axis='y', which='minor', length=4)
            ax.tick_params(axis='x', rotation=45)
            
            ax.grid(True, axis='y', color="lightgray", linestyle="--", linewidth=0.7, alpha=0.7)
            
            # Add legend only to the first subplot to avoid repetition
            if idx == 0:
                ax.legend(fontsize=10, loc='upper left')
        
        # Main title for the entire figure
        fig.suptitle(f"{models_dict[model]} Performance across Demographic Targets", 
                    fontsize=16, fontweight='bold', y=1.02)
        
        fig.tight_layout()
        
        # Save as PDF
        fig.savefig(f"{cohort_name}_Demographic_Target_{model}_metrics.pdf", 
                   format="pdf", bbox_inches='tight', dpi=300)
        plt.close(fig)

# Generate plots
plot_demographic_roc_pr(apl_demographic_df, "APL")

# %% [markdown]
# # Neutropenic Fever Cohort

# %%
import pandas as pd

nf_data = [
    # Features X
    ("X", "RF", 0.30, 0.05, 0.24, 0.05, 0.78, 0.02, 0.17, 0.04),
    ("X", "GB", 0.12, 0.05, 0.16, 0.05, 0.76, 0.02, 0.18, 0.02),
    ("X", "LR", 0.43, 0.07, 0.13, 0.02, 0.61, 0.06, 0.07, 0.01),
    ("X", "XGB", 0.22, 0.04, 0.23, 0.04, 0.78, 0.04, 0.20, 0.06),
    ("X", "CB", 0.38, 0.20, 0.21, 0.04, 0.78, 0.02, 0.19, 0.06),

    # Features M
    ("M", "RF", 0.45, 0.16, 0.18, 0.03, 0.68, 0.05, 0.12, 0.03),
    ("M", "GB", 0.33, 0.10, 0.17, 0.07, 0.68, 0.06, 0.11, 0.04),
    ("M", "LR", 0.29, 0.02, 0.15, 0.02, 0.65, 0.03, 0.09, 0.01),
    ("M", "XGB", 0.52, 0.16, 0.16, 0.03, 0.68, 0.05, 0.11, 0.02),
    ("M", "CB", 0.41, 0.05, 0.17, 0.04, 0.70, 0.05, 0.12, 0.03),

    # Features D
    ("D", "RF", 0.42, 0.08, 0.16, 0.04, 0.72, 0.04, 0.11, 0.03),
    ("D", "GB", 0.29, 0.07, 0.18, 0.05, 0.69, 0.04, 0.11, 0.04),
    ("D", "LR", 0.38, 0.12, 0.16, 0.06, 0.66, 0.05, 0.09, 0.02),
    ("D", "XGB", 0.42, 0.12, 0.17, 0.04, 0.70, 0.05, 0.11, 0.02),
    ("D", "CB", 0.55, 0.18, 0.16, 0.03, 0.72, 0.04, 0.12, 0.03),

    # Features XD
    ("XD", "RF", 0.31, 0.06, 0.24, 0.06, 0.78, 0.02, 0.18, 0.05),
    ("XD", "GB", 0.12, 0.02, 0.16, 0.01, 0.76, 0.05, 0.17, 0.03),
    ("XD", "LR", 0.43, 0.07, 0.13, 0.02, 0.61, 0.06, 0.07, 0.01),
    ("XD", "XGB", 0.30, 0.12, 0.25, 0.06, 0.77, 0.04, 0.20, 0.07),
    ("XD", "CB", 0.48, 0.15, 0.23, 0.04, 0.78, 0.02, 0.20, 0.07),

    # Features MD
    ("MD", "RF", 0.41, 0.05, 0.18, 0.03, 0.72, 0.04, 0.11, 0.02),
    ("MD", "GB", 0.26, 0.07, 0.17, 0.07, 0.68, 0.03, 0.12, 0.05),
    ("MD", "LR", 0.26, 0.04, 0.15, 0.02, 0.65, 0.03, 0.08, 0.02),
    ("MD", "XGB", 0.39, 0.14, 0.16, 0.03, 0.69, 0.06, 0.11, 0.01),
    ("MD", "CB", 0.52, 0.18, 0.17, 0.04, 0.72, 0.06, 0.11, 0.03),

    # Features XMD
    ("XMD", "RF", 0.84, 0.04, 0.60, 0.03, 0.84, 0.02, 0.62, 0.04),
    ("XMD", "GB", 0.15, 0.05, 0.19, 0.07, 0.76, 0.03, 0.18, 0.10),
    ("XMD", "LR", 0.69, 0.05, 0.46, 0.01, 0.68, 0.02, 0.37, 0.00),
    ("XMD", "XGB", 0.28, 0.14, 0.25, 0.10, 0.77, 0.03, 0.20, 0.08),
    ("XMD", "CB", 0.49, 0.22, 0.23, 0.02, 0.79, 0.02, 0.20, 0.03),
]

nf_df = pd.DataFrame(nf_data, columns=[
    "Features", "Model",
    "Recall_mean", "Recall_std",
    "F1_mean", "F1_std",
    "ROC_mean", "ROC_std",
    "PR_mean", "PR_std"
])

nf_df.head()
# Out:
#   Features Model  Recall_mean  Recall_std  F1_mean  F1_std  ROC_mean  ROC_std  \
# 0        X    RF         0.30        0.05     0.24    0.05      0.78     0.02
# 1        X    GB         0.12        0.05     0.16    0.05      0.76     0.02
# 2        X    LR         0.43        0.07     0.13    0.02      0.61     0.06
# 3        X   XGB         0.22        0.04     0.23    0.04      0.78     0.04
# 4        X    CB         0.38        0.20     0.21    0.04      0.78     0.02
#
#    PR_mean  PR_std
# 0     0.17    0.04
# 1     0.18    0.02
# 2     0.07    0.01
# 3     0.20    0.06
# 4     0.19    0.06

# %%
nf_df[nf_df["Model"] == "LR"]
# Out:
#    Features Model  Recall_mean  Recall_std  F1_mean  F1_std  ROC_mean  \
# 2         X    LR         0.43        0.07     0.13    0.02      0.61
# 7         M    LR         0.29        0.02     0.15    0.02      0.65
# 12        D    LR         0.38        0.12     0.16    0.06      0.66
# 17       XD    LR         0.43        0.07     0.13    0.02      0.61
# 22       MD    LR         0.26        0.04     0.15    0.02      0.65
# 27      XMD    LR         0.69        0.05     0.46    0.01      0.68
#
#     ROC_std  PR_mean  PR_std
# 2      0.06     0.07    0.01
# 7      0.03     0.09    0.01
# 12     0.05     0.09    0.02
# 17     0.06     0.07    0.01
# 22     0.03     0.08    0.02
# 27     0.02     0.37    0.00

# %%
plot_model_performance(nf_df, "NF", "Clinical_Target")

# %%
import pandas as pd

nf_demographic = [
    # Target: Gender
    ("Gender", "M", "RF", 0.58, 0.06, 0.56, 0.05, 0.51, 0.04, 0.56, 0.06),
    ("Gender", "M", "GB", 0.55, 0.01, 0.56, 0.01, 0.54, 0.02, 0.57, 0.04),
    ("Gender", "M", "LR", 0.56, 0.03, 0.56, 0.03, 0.53, 0.04, 0.56, 0.05),
    ("Gender", "M", "XGB", 0.94, 0.04, 0.68, 0.05, 0.51, 0.02, 0.55, 0.06),
    ("Gender", "M", "CB", 0.53, 0.16, 0.52, 0.09, 0.52, 0.05, 0.53, 0.06),

    ("Gender", "D", "RF", 0.59, 0.06, 0.57, 0.04, 0.54, 0.04, 0.58, 0.06),
    ("Gender", "D", "GB", 0.57, 0.03, 0.57, 0.03, 0.56, 0.02, 0.59, 0.04),
    ("Gender", "D", "LR", 0.59, 0.02, 0.57, 0.03, 0.54, 0.03, 0.57, 0.06),
    ("Gender", "D", "XGB", 0.94, 0.03, 0.69, 0.05, 0.53, 0.05, 0.57, 0.07),
    ("Gender", "D", "CB", 0.65, 0.16, 0.60, 0.09, 0.54, 0.05, 0.57, 0.07),

    ("Gender", "MD", "RF", 0.57, 0.06, 0.56, 0.04, 0.53, 0.04, 0.57, 0.06),
    ("Gender", "MD", "GB", 0.59, 0.01, 0.58, 0.01, 0.56, 0.01, 0.59, 0.02),
    ("Gender", "MD", "LR", 0.56, 0.04, 0.56, 0.04, 0.54, 0.03, 0.57, 0.05),
    ("Gender", "MD", "XGB", 0.94, 0.04, 0.69, 0.04, 0.53, 0.04, 0.57, 0.07),
    ("Gender", "MD", "CB", 0.58, 0.07, 0.56, 0.06, 0.53, 0.05, 0.57, 0.07),

    # Target: Race
    ("Race", "M", "RF", 0.45, 0.05, 0.42, 0.03, 0.54, 0.02, 0.40, 0.03),
    ("Race", "M", "GB", 0.53, 0.03, 0.48, 0.03, 0.57, 0.02, 0.44, 0.05),
    ("Race", "M", "LR", 0.49, 0.02, 0.45, 0.03, 0.55, 0.02, 0.42, 0.04),
    ("Race", "M", "XGB", 0.85, 0.05, 0.53, 0.03, 0.56, 0.01, 0.43, 0.03),
    ("Race", "M", "CB", 0.53, 0.04, 0.47, 0.03, 0.55, 0.01, 0.42, 0.03),

    ("Race", "D", "RF", 0.94, 0.03, 0.54, 0.04, 0.55, 0.03, 0.41, 0.03),
    ("Race", "D", "GB", 0.46, 0.04, 0.44, 0.05, 0.55, 0.02, 0.42, 0.04),
    ("Race", "D", "LR", 0.49, 0.01, 0.44, 0.03, 0.54, 0.02, 0.42, 0.03),
    ("Race", "D", "XGB", 0.78, 0.09, 0.52, 0.05, 0.56, 0.02, 0.43, 0.04),
    ("Race", "D", "CB", 0.49, 0.02, 0.47, 0.03, 0.55, 0.01, 0.42, 0.03),

    ("Race", "MD", "RF", 0.94, 0.03, 0.54, 0.04, 0.54, 0.03, 0.41, 0.03),
    ("Race", "MD", "GB", 0.46, 0.01, 0.44, 0.01, 0.56, 0.02, 0.42, 0.03),
    ("Race", "MD", "LR", 0.47, 0.02, 0.44, 0.03, 0.55, 0.03, 0.42, 0.04),
    ("Race", "MD", "XGB", 0.72, 0.01, 0.52, 0.05, 0.55, 0.01, 0.42, 0.03),
    ("Race", "MD", "CB", 0.50, 0.04, 0.46, 0.04, 0.56, 0.02, 0.43, 0.03),

    # Target: Age
    ("Age", "M", "RF", 0.69, 0.03, 0.75, 0.02, 0.61, 0.02, 0.83, 0.03),
    ("Age", "M", "GB", 0.72, 0.03, 0.77, 0.01, 0.61, 0.03, 0.83, 0.01),
    ("Age", "M", "LR", 0.70, 0.01, 0.75, 0.01, 0.59, 0.03, 0.83, 0.03),
    ("Age", "M", "XGB", 0.86, 0.05, 0.83, 0.02, 0.62, 0.02, 0.84, 0.03),
    ("Age", "M", "CB", 0.64, 0.06, 0.72, 0.04, 0.63, 0.04, 0.84, 0.04),

    ("Age", "D", "RF", 0.72, 0.03, 0.77, 0.02, 0.63, 0.02, 0.84, 0.03),
    ("Age", "D", "GB", 0.73, 0.03, 0.77, 0.02, 0.63, 0.06, 0.84, 0.03),
    ("Age", "D", "LR", 0.68, 0.02, 0.75, 0.01, 0.62, 0.05, 0.84, 0.04),
    ("Age", "D", "XGB", 0.84, 0.08, 0.82, 0.04, 0.63, 0.04, 0.84, 0.03),
    ("Age", "D", "CB", 0.66, 0.02, 0.74, 0.01, 0.65, 0.03, 0.85, 0.03),

    ("Age", "MD", "RF", 0.73, 0.04, 0.77, 0.03, 0.63, 0.03, 0.84, 0.03),
    ("Age", "MD", "GB", 0.74, 0.02, 0.78, 0.02, 0.62, 0.02, 0.84, 0.03),
    ("Age", "MD", "LR", 0.70, 0.01, 0.75, 0.01, 0.61, 0.04, 0.84, 0.03),
    ("Age", "MD", "XGB", 0.89, 0.03, 0.84, 0.01, 0.63, 0.02, 0.84, 0.03),
    ("Age", "MD", "CB", 0.67, 0.06, 0.74, 0.04, 0.65, 0.03, 0.85, 0.03),
]

nf_demographic_df = pd.DataFrame(nf_demographic, columns=[
    "Target", "Features", "Model",
    "Recall_mean", "Recall_std",
    "F1_mean", "F1_std",
    "ROC_mean", "ROC_std",
    "PR_mean", "PR_std"
])

nf_demographic_df.head()
# Out:
#    Target Features Model  Recall_mean  Recall_std  F1_mean  F1_std  ROC_mean  \
# 0  Gender        M    RF         0.58        0.06     0.56    0.05      0.51
# 1  Gender        M    GB         0.55        0.01     0.56    0.01      0.54
# 2  Gender        M    LR         0.56        0.03     0.56    0.03      0.53
# 3  Gender        M   XGB         0.94        0.04     0.68    0.05      0.51
# 4  Gender        M    CB         0.53        0.16     0.52    0.09      0.52
#
#    ROC_std  PR_mean  PR_std
# 0     0.04     0.56    0.06
# 1     0.02     0.57    0.04
# 2     0.04     0.56    0.05
# 3     0.02     0.55    0.06
# 4     0.05     0.53    0.06

# %%
plot_demographic_roc_pr(nf_demographic_df, "NF")
